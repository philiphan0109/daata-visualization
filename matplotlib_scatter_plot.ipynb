# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use("seaborn-v0_8")

# %%
### Sample Data

# x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
# y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

# colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
# sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174, 538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]

# plt.scatter(x, y, s = 100, c = colors, cmap = "Blues", sizes=sizes, edgecolors="black", linewidths=1, alpha = 0.5)

# cbar = plt.colorbar()
# cbar.set_label("Saturation")

### CSV File

data = pd.read_csv("data/scatter_plot_data.csv")
views = data["view_count"]
likes = data["likes"]
ratio = data["ratio"]

plt.scatter(views, likes, c = ratio, cmap = "inferno", edgecolor="black", linewidth=1, alpha = 0.5)
cbar = plt.colorbar()
cbar.set_label("Like/Dislike Ratio")

plt.xscale("log")
plt.yscale("log")

plt.title("Trending Youtube Videos")
plt.xlabel("Views")
plt.ylabel("Likes")
plt.tight_layout()
